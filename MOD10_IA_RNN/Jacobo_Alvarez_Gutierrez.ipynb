# %% [markdown]
# Dado que el entrenamiento de redes neuronales es una tarea  muy costosa, **se recomienda ejecutar el notebooks en [Google Colab](https://colab.research.google.com)**, por supuesto también se puede ejecutar en local.
#
# Al entrar en [Google Colab](https://colab.research.google.com) bastará con hacer click en `upload` y subir este notebook. No olvide luego descargarlo en `File->Download .ipynb`
#
# **El examen deberá ser entregado con las celdas ejecutadas, si alguna celda no está ejecutadas no se contará.**

# %% [markdown]
# El examen se divide en tres partes, con la puntuación que se indica a continuación. La puntuación máxima será 10.
#
#
# - [Actividad 1: Redes Recurrentes](#actividad_1): 10 pts
#     - [Cuestión 1](#3.1): 2.5 pt
#     - [Cuestión 2](#3.2): 2.5 pt
#     - [Cuestión 3](#3.3): 2.5 pts
#     - [Cuestión 4](#3.4): 1.25 pts
#     - [Cuestión 5](#3.5): 1.25 pts

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <a name='actividad_1'></a>
# # Actividad 1: Redes Recurrentes
#
#
# - [Cuestión 1](#3.1): 2.5 pt
# - [Cuestión 2](#3.2): 2.5 pt
# - [Cuestión 3](#3.3): 2.5 pts
# - [Cuestión 4](#3.4): 1.25 pts
# - [Cuestión 5](#3.5): 1.25 pts
#
# Vamos a usar un dataset de las temperaturas mínimas diarias en Melbourne. La tarea será la de predecir la temperatura mínima en dos días. Puedes usar técnicas de series temporales vistas en otras asignaturas, pero no es necesario.

# %%
dataset_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv'
data_dir = tf.keras.utils.get_file('daily-min-temperatures.csv', origin=dataset_url)

# %%
df = pd.read_csv(data_dir, parse_dates=['Date'])
df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
temperatures = df['Temp'].values
print('number of samples:', len(temperatures))
train_data = temperatures[:3000]
test_data = temperatures[3000:]
print('number of train samples:', len(train_data))
print('number of test samples:', len(test_data))
print('firsts trainn samples:', train_data[:10])
# Out:
# number of samples: 3650
# number of train samples: 3000
# number of test samples: 650
# firsts trainn samples: [20.7 17.9 18.8 14.6 15.8 15.8 15.8 17.4 21.8 20. ]

# %% [markdown]
# <a name='3.1'></a>
# ## Cuestión 1: Convierta `train_data` y `test_data`  en ventanas de tamaño 5, para predecir el valor en 2 días
#
# En la nomenclatura de [Introduction_to_RNN_Time_Series.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/RNN/Introduction_to_RNN_Time_Series.ipynb)
# ```python
# past, future = (5, 2)
# ```
#
# Para las primeras 10 muestras de train_data `[20.7, 17.9, 18.8, 14.6, 15.8, 15.8, 15.8, 17.4, 21.8, 20. ]` el resultado debería ser:
#
# ```python
# x[0] : [20.7, 17.9, 18.8, 14.6, 15.8] , y[0]: 15.8
# x[1] : [17.9, 18.8, 14.6, 15.8, 15.8] , y[1]: 17.4
# x[2] : [18.8, 14.6, 15.8, 15.8, 15.8] , y[2]: 21.8
# x[3] : [14.6, 15.8, 15.8, 15.8, 17.4] , y[3]: 20.
# ```

# %%
# windowing function
def create_windows(data, window_size, horizon, target_col_idx=0, shuffle=False):
    X, y = [], []
    if data.ndim == 1:
        data = data[:, np.newaxis]

    for i in range(len(data) - window_size - horizon + 1):
        x_i = data[i:i + window_size]
        y_i = data[i + window_size + horizon - 1, target_col_idx]
        X.append(x_i)
        y.append(y_i)

    X, y = np.array(X), np.array(y)

    if shuffle:
        indices = np.arange(len(X))
        np.random.shuffle(indices)
        X, y = X[indices], y[indices]

    return X, y

# %%
past, future = (5, 2)
X_train, y_train = create_windows(train_data, past, future)
X_test, y_test = create_windows(test_data, past, future)

# %% [markdown]
# <a name='3.2'></a>
# ## Cuestión 2: Cree un modelo recurrente de dos capas GRU para predecir con las ventanas de la cuestión anterior.

# %%
normalizer = keras.layers.Normalization()
normalizer.adapt(X_train)

inputs = keras.layers.Input(shape=(past, 1))
norm_inputs = normalizer(inputs)
gru_1 = keras.layers.GRU(64, return_sequences=True,
                         dropout=0.2, recurrent_dropout=0.2)(norm_inputs)
gru_2 = keras.layers.GRU(64, dropout=0.2, recurrent_dropout=0.2)(gru_1)
outputs = keras.layers.Dense(1)(gru_2)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization (Normalization)   │ (None, 5, 1)           │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 5, 64)          │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 64)             │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,892 (148.02 KB)
#  Trainable params: 37,889 (148.00 KB)
#  Non-trainable params: 3 (16.00 B)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=10)

history = model.fit(
    X_train, y_train,
    epochs=200,
    validation_split=0.2, shuffle=True, batch_size = 64, callbacks=[es_callback]
)
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 119.3631 - mae: 10.2077 - val_loss: 15.2857 - val_mae: 3.1078
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 15.7960 - mae: 3.1748 - val_loss: 13.6245 - val_mae: 2.9266
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 13.6479 - mae: 2.8929 - val_loss: 11.8658 - val_mae: 2.7017
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 12.6457 - mae: 2.7732 - val_loss: 10.4794 - val_mae: 2.5301
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 11.2721 - mae: 2.6051 - val_loss: 9.7096 - val_mae: 2.4323
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 10.5657 - mae: 2.5332 - val_loss: 9.4175 - val_mae: 2.3863
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 10.7453 - mae: 2.5514 - val_loss: 8.9287 - val_mae: 2.3084
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 10.0093 - mae: 2.4918 - val_loss: 8.8220 - val_mae: 2.2935
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.0064 - mae: 2.4623 - val_loss: 9.0431 - val_mae: 2.3257
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 10.7287 - mae: 2.5713 - val_loss: 8.7592 - val_mae: 2.2801
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.7314 - mae: 2.4295 - val_loss: 8.6836 - val_mae: 2.2707
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 9.6901 - mae: 2.4235 - val_loss: 8.8713 - val_mae: 2.2955
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.2269 - mae: 2.3962 - val_loss: 8.6163 - val_mae: 2.2638
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.4116 - mae: 2.3952 - val_loss: 8.6035 - val_mae: 2.2582
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.4262 - mae: 2.3956 - val_loss: 8.4202 - val_mae: 2.2307
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.7260 - mae: 2.4097 - val_loss: 8.3879 - val_mae: 2.2342
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 9.1601 - mae: 2.3629 - val_loss: 8.4571 - val_mae: 2.2428
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.1936 - mae: 2.3762 - val_loss: 8.4216 - val_mae: 2.2411
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.3090 - mae: 2.3863 - val_loss: 8.7131 - val_mae: 2.2700
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.7832 - mae: 2.4407 - val_loss: 8.2831 - val_mae: 2.2229
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.7551 - mae: 2.4402 - val_loss: 8.3733 - val_mae: 2.2328
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.5675 - mae: 2.4520 - val_loss: 8.2817 - val_mae: 2.2199
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 9.6101 - mae: 2.3963 - val_loss: 8.3801 - val_mae: 2.2279
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 9.3542 - mae: 2.3844 - val_loss: 8.7842 - val_mae: 2.2782
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.2105 - mae: 2.3677 - val_loss: 8.2951 - val_mae: 2.2203
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.8987 - mae: 2.3414 - val_loss: 8.3770 - val_mae: 2.2266
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.2204 - mae: 2.3770 - val_loss: 8.2904 - val_mae: 2.2242
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.0455 - mae: 2.3573 - val_loss: 8.4050 - val_mae: 2.2277
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 9.3376 - mae: 2.3735 - val_loss: 8.3284 - val_mae: 2.2294
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 9.2378 - mae: 2.3912 - val_loss: 8.2828 - val_mae: 2.2228
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 8.9007 - mae: 2.3444 - val_loss: 8.2273 - val_mae: 2.2228
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.1401 - mae: 2.3873 - val_loss: 8.3470 - val_mae: 2.2293
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.3934 - mae: 2.4015 - val_loss: 8.3317 - val_mae: 2.2397
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 9.2168 - mae: 2.3838 - val_loss: 8.1795 - val_mae: 2.2040
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 8.9255 - mae: 2.3495 - val_loss: 8.3351 - val_mae: 2.2250
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.9269 - mae: 2.3352 - val_loss: 8.1835 - val_mae: 2.2034
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.4868 - mae: 2.2846 - val_loss: 8.2283 - val_mae: 2.2127
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4409 - mae: 2.4257 - val_loss: 8.3804 - val_mae: 2.2289
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.1481 - mae: 2.3871 - val_loss: 8.2295 - val_mae: 2.2162
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 8.8521 - mae: 2.3048 - val_loss: 8.2574 - val_mae: 2.2154
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 8.9256 - mae: 2.3523 - val_loss: 8.4137 - val_mae: 2.2341
# Epoch 42/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.9086 - mae: 2.3137 - val_loss: 8.2125 - val_mae: 2.2166
# Epoch 43/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 8.9437 - mae: 2.3226 - val_loss: 8.2259 - val_mae: 2.2053
# Epoch 44/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.2007 - mae: 2.3813 - val_loss: 8.1680 - val_mae: 2.1999
# Epoch 45/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 9.7118 - mae: 2.4395 - val_loss: 8.1486 - val_mae: 2.1947
# Epoch 46/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 8.8879 - mae: 2.3352 - val_loss: 8.1974 - val_mae: 2.2074
# Epoch 47/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.8281 - mae: 2.3300 - val_loss: 8.2455 - val_mae: 2.2094
# Epoch 48/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.2475 - mae: 2.3875 - val_loss: 8.2723 - val_mae: 2.2140
# Epoch 49/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.7701 - mae: 2.2968 - val_loss: 8.1214 - val_mae: 2.1945
# Epoch 50/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.4814 - mae: 2.2855 - val_loss: 8.4255 - val_mae: 2.2356
# Epoch 51/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.3534 - mae: 2.3729 - val_loss: 8.2315 - val_mae: 2.2095
# Epoch 52/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 8.7279 - mae: 2.3190 - val_loss: 8.4251 - val_mae: 2.2300
# Epoch 53/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 8.6599 - mae: 2.2795 - val_loss: 8.3063 - val_mae: 2.2153
# Epoch 54/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 9.1413 - mae: 2.3442 - val_loss: 8.2083 - val_mae: 2.2017
# Epoch 55/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.2366 - mae: 2.3746 - val_loss: 8.2954 - val_mae: 2.2170
# Epoch 56/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.0057 - mae: 2.3483 - val_loss: 8.2264 - val_mae: 2.2057
# Epoch 57/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 8.8643 - mae: 2.3179 - val_loss: 8.1301 - val_mae: 2.1905
# Epoch 58/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.1685 - mae: 2.3705 - val_loss: 8.4308 - val_mae: 2.2329
# Epoch 59/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.5739 - mae: 2.3116 - val_loss: 8.1041 - val_mae: 2.1871
# Epoch 60/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.9533 - mae: 2.3372 - val_loss: 8.2628 - val_mae: 2.2037
# Epoch 61/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.2218 - mae: 2.3709 - val_loss: 8.3257 - val_mae: 2.2199
# Epoch 62/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.9903 - mae: 2.3337 - val_loss: 8.2084 - val_mae: 2.2012
# Epoch 63/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.0246 - mae: 2.3607 - val_loss: 8.0772 - val_mae: 2.1873
# Epoch 64/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 9.3768 - mae: 2.3968 - val_loss: 8.1228 - val_mae: 2.1924
# Epoch 65/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.0602 - mae: 2.3488 - val_loss: 8.1670 - val_mae: 2.1980
# Epoch 66/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.1601 - mae: 2.3664 - val_loss: 8.1848 - val_mae: 2.1981
# Epoch 67/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.6039 - mae: 2.2932 - val_loss: 8.2336 - val_mae: 2.2060
# Epoch 68/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.9775 - mae: 2.3340 - val_loss: 8.1795 - val_mae: 2.1994
# Epoch 69/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.7062 - mae: 2.3107 - val_loss: 8.4220 - val_mae: 2.2396
# Epoch 70/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.1252 - mae: 2.3404 - val_loss: 8.1840 - val_mae: 2.2000
# Epoch 71/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.0994 - mae: 2.3534 - val_loss: 8.1480 - val_mae: 2.1957
# Epoch 72/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.0900 - mae: 2.3512 - val_loss: 8.2183 - val_mae: 2.2064
# Epoch 73/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.6343 - mae: 2.2775 - val_loss: 8.1837 - val_mae: 2.1997

# %%
results = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9318 - mae: 2.0619
# Test Loss: [6.9029388427734375, 2.0545971393585205]

# %% [markdown]
# <a name='3.3'></a>
# ## Cuestión 3: Añada más features a la series temporal, por ejemplo `portion_year`. Cree un modelo que mejore al anterior.

# %%
## Puede añadir más features
df['portion_year'] = df['Date'].dt.dayofyear / 365.0

df['year_sin'] = np.sin(2 * np.pi * df['portion_year'])
df['year_cos'] = np.cos(2 * np.pi * df['portion_year'])

df['month'] = df['Date'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['dayofweek'] = df['Date'].dt.dayofweek
df['dow_sin'] = np.sin(2 * np.pi * df['dayofweek'] / 7)
df['dow_cos'] = np.cos(2 * np.pi * df['dayofweek'] / 7)

df_multi = df[['Temp', 'portion_year', 'year_sin', 'year_cos',
               'month_sin', 'month_cos', 'dow_sin', 'dow_cos']].copy()

## train - test split
train_data = df_multi.iloc[:3000].copy()
test_data = df_multi.loc[3000:, :].copy()

# %%
## Create windows
X_train, y_train = create_windows(train_data.to_numpy(),
                                  past, future, target_col_idx=0)
X_test, y_test = create_windows(test_data.to_numpy(),
                                past, future, target_col_idx=0)

# %%
normalizer = keras.layers.Normalization()
normalizer.adapt(X_train)

inputs = keras.layers.Input(shape=(past, 8))
norm_inputs = normalizer(inputs)
gru_1 = keras.layers.GRU(128, return_sequences=True,
                         dropout=0.2, recurrent_dropout=0.2)(norm_inputs)
gru_2 = keras.layers.GRU(128, dropout=0.2, recurrent_dropout=0.2)(gru_1)
outputs = keras.layers.Dense(1)(gru_2)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 8)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_1 (Normalization) │ (None, 5, 8)           │            17 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 5, 128)         │        52,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 152,210 (594.57 KB)
#  Trainable params: 152,193 (594.50 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=10)

history = model.fit(
    X_train, y_train,
    epochs=200,
    validation_split=0.2, shuffle=True, batch_size = 64, callbacks=[es_callback]
)
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 107.2134 - mae: 9.4748 - val_loss: 10.4425 - val_mae: 2.5658
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.0043 - mae: 2.5106 - val_loss: 7.9446 - val_mae: 2.1846
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.0915 - mae: 2.4049 - val_loss: 7.8277 - val_mae: 2.1757
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.2012 - mae: 2.2773 - val_loss: 8.0109 - val_mae: 2.1966
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 8.7314 - mae: 2.3351 - val_loss: 7.5077 - val_mae: 2.1154
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 7.7465 - mae: 2.2314 - val_loss: 7.7467 - val_mae: 2.1616
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.0406 - mae: 2.2711 - val_loss: 7.7223 - val_mae: 2.1322
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 7.6630 - mae: 2.1914 - val_loss: 8.0432 - val_mae: 2.1981
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.4420 - mae: 2.3062 - val_loss: 7.9075 - val_mae: 2.1603
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 8.1186 - mae: 2.2521 - val_loss: 8.0666 - val_mae: 2.1774
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.9781 - mae: 2.2350 - val_loss: 7.6759 - val_mae: 2.1383
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.1158 - mae: 2.2666 - val_loss: 7.7779 - val_mae: 2.1417
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.4575 - mae: 2.3024 - val_loss: 7.9119 - val_mae: 2.1670
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.6676 - mae: 2.1878 - val_loss: 7.8556 - val_mae: 2.1672
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.0493 - mae: 2.2460 - val_loss: 7.7285 - val_mae: 2.1629

# %%
results = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1384 - mae: 1.9565
# Test Loss: [6.228333473205566, 1.950204610824585]

# %% [markdown]
# <a name='3.4'></a>
# ## Cuestión 4: ¿En cuáles de estas aplicaciones se usaría un arquitectura 'many-to-one'?
#
# **a)** Clasificación de sentimiento en textos
#
# **b)** Verificación de voz para iniciar el ordenador.
#
# **c)** Generación de música.
#
# **d)** Un clasificador que clasifique piezas de música según su autor.

# %% [markdown]
# ---
# La arquitectura 'many-to-one' es apta para A(Clasificación de sentimiento en textos), B(Verificación de voz para iniciar el ordenador) y C(Un clasificador que clasifique piezas de música según su autor). Esto es así puesto que son varios los respectivos inputs y un solo output (cadena de texto--> sentimiento, cadena de audio-->orden, cadena de audio-->autor).
#
# Por el contrario, C(Generación de música) no es apta para esta arquitectura puesto se espera como salida una cadena de audio.
#
# ---

# %% [markdown]
# <a name='3.5'></a>
# ## Cuestión 5: ¿Qué ventajas aporta el uso de word embeddings?
#
# **a)** Permiten reducir la dimensión de entrada respecto al one-hot encoding.
#
# **b)** Permiten descubrir la similaridad entre palabras de manera más intuitiva que con one-hot encoding.
#
# **c)** Son una manera de realizar transfer learning en nlp.
#
# **d)** Permiten visualizar las relaciones entre palabras con métodos de reducción de dimensioones como el PCA.

# %% [markdown]
# ---
# Todas las opciones anteriores son correctas. En efecto, al usar one-hot encoding se generan vectores tan largos como la longitud del diccionario, siendo todos los vectores igual de diferentes entre sí. Al usar word embeddings se obtienen vectores de una longitud fija cuya cercanía representa similitud entre palabras (a, b y c). Además, como a estos vectores se le asigna una dimensión fija se podría aplicar una técnica de reducción de componentes como PCA para realizar agrupaciones semánticas entre las palabras (d).
#
# ---
